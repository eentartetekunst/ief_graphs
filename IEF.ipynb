# %%
from mpl_toolkits.axes_grid1 import host_subplot
import mpl_toolkits.axisartist as AA
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
fractions = [i for i in range(1,51)] # количество фракций
phs = [1.93, 1.47,1.45,1.39,1.40,1.41,1.42,1.76,2.16,2.69,3.19,3.54,3.92,4.11,4.29,4.45,4.62,4.80,4.93,5.08,5.57,5.54,5.67,5.83,5.97,6.03,6.19,6.38,6.66,6.72,7.03,7.05,7.22,7.57,7.74,7.79,8.06,8.01,8.16,8.33,8.38,8.59,8.70,8.85,9.01,9.32,10.26,11.28,11.57, 12.10]
a280 = [0.538, 0.523,0.518,0.648,0.685,1.15,5,5,5,2.056,2.166,2.798,2.855,1.213,0.566,0.449,0.325,0.281,0.308,0.432,0.321,0.421,0.535,0.576,0.615,0.467,0.278,0.267,0.269,0.162,0.089,0.098,0.222,0.061,0.076,0.036,0.019,0.032,0.045,0.065,0.055,0.052,0.037,0.052,0.02,0.03,0.066,0.176,0.065,0.002]
sel_frac = [11,12,13,14,15,16,17,18,22,23,24,32,33,34,47,48,49]
dval = [0, 0.027,0.179, 0.693,1.391,1.447,0.593,0.207,0.075,0.045,0.038,0.074,0.02,0.003,0.001,0,0.001]
cas = [0,0.035,0.025,0.131,0.551,0.72,0.165,0.021,0.023,0.008,0.006,0.032,0.01,0.043,0.057,0.188, 0.011]

# %%
import matplotlib.pyplot as plt


fig, ax = plt.subplots()
fig.subplots_adjust(right=0.8)

twin1 = ax.twinx()
twin2 = ax.twinx()
twin3 = ax.twinx()

twin2.spines.right.set_position(("axes", 1.2))
twin3.spines.right.set_position(("axes", -0.3))


p1, = ax.plot(fractions, phs, "b-", label="pH")
p2, = twin1.plot(fractions, a280, "r-", label="A280")
p3, = twin2.plot(sel_frac, dval, "g-", label="dVal")
p4, = twin3.plot(sel_frac, cas, "y-", label="cas", )


ax.set_xlabel("Номер фракции")
ax.set_ylabel("pH")
twin1.set_ylabel("А280")
twin2.set_ylabel("dVal")
twin3.set_ylabel("Казеинолиз")

ax.yaxis.label.set_color(p1.get_color())
twin1.yaxis.label.set_color(p2.get_color())
twin2.yaxis.label.set_color(p3.get_color())
twin3.yaxis.label.set_color(p4.get_color())


tkw = dict(size=4, width=1.5)
ax.tick_params(axis='y', colors=p1.get_color(), **tkw)
twin1.tick_params(axis='y', colors=p2.get_color(), **tkw)
twin2.tick_params(axis='y', colors=p3.get_color(), **tkw)
twin3.tick_params(axis='y', colors=p4.get_color(), **tkw)
ax.tick_params(axis='x', **tkw)

ax.legend(loc='upper right', handles=[p1, p2, p3, p4])

plt.savefig('test.jpg', dpi=1000, bbox_inches = 'tight')
